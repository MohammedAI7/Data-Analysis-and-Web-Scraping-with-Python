# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("companies_by_revenue.csv")

# %%
df.columns
# Out:
# Index(['Rank', 'Forbes rank', 'Name', 'city', 'Revenue(billions US$)',
#        'Profit(billions US$)', 'Assets(billions US$)', 'Value(billions US$)',
#        'Industry'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   71 non-null     int64
#  1   Forbes rank            71 non-null     int64
#  2   Name                   71 non-null     object
#  3   city                   71 non-null     object
#  4   Revenue(billions US$)  71 non-null     float64
#  5   Profit(billions US$)   71 non-null     float64
#  6   Assets(billions US$)   71 non-null     float64
#  7   Value(billions US$)    71 non-null     float64
#  8   Industry               71 non-null     object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 5.1+ KB

# %%
df.describe()
# Out:
#             Rank  Forbes rank  Revenue(billions US$)  Profit(billions US$)  \
# count  71.000000    71.000000              71.000000             71.000000
# mean   35.408451  1048.267606              17.812676              1.708451
# std    19.920971   608.968729              23.347499              1.920175
# min     1.000000    49.000000               0.200000              0.000000
# 25%    18.500000   535.000000               4.150000              0.500000
# 50%    36.000000   947.000000              10.800000              0.900000
# 75%    51.500000  1695.000000              17.750000              2.250000
# max    69.000000  1980.000000             108.800000              8.400000
#
#        Assets(billions US$)  Value(billions US$)
# count             71.000000            71.000000
# mean              71.621127            33.588732
# std              132.730041            37.901853
# min                1.300000             1.100000
# ...

# %%
df.shape
# Out:
# (71, 9)

# %%
df.head(5)
# Out:
#    Rank  Forbes rank                         Name       city  \
# 0     1           49  Reliance Industries Limited     Mumbai
# 1     2           55          State Bank of India     Mumbai
# 2     3           65                    HDFC Bank     Mumbai
# 3     4           70   Life Insurance Corporation  New Delhi
# 4     5          142                   ICICI Bank     Mumbai
#
#    Revenue(billions US$)  Profit(billions US$)  Assets(billions US$)  \
# 0                  108.8                   8.4                 210.5
# 1                   71.8                   8.1                 807.4
# 2                   49.3                   7.7                 483.2
# 3                   98.0                   4.9                 561.4
# 4                   28.5                   5.3                 283.5
#
#    Value(billions US$)      Industry
# 0                233.1  Conglomerate
# 1                 87.6       Banking
# 2                133.6       Banking
# ...

# %%
df.tail(5)
# Out:
#     Rank  Forbes rank                      Name       city  \
# 66    65         1895  Dr. Reddy's Laboratories  Hyderabad
# 67    66         1908           Varun Beverages    Gurgaon
# 68    67         1949                     CIFCL    Chennai
# 69    68         1957                      NMDC  Hyderabad
# 70    69         1980                 ABB India  Bangalore
#
#     Revenue(billions US$)  Profit(billions US$)  Assets(billions US$)  \
# 66                    3.4                   0.7                   4.6
# 67                    2.0                   0.3                   1.8
# 68                    2.3                   0.4                  18.8
# 69                    2.5                   0.8                   3.9
# 70                    1.3                   0.2                   1.3
#
#     Value(billions US$)         Industry
# 66                 11.6  Pharmaceuticals
# 67                 23.6        Beverages
# 68                 13.0       Financials
# ...

# %%
df.set_index("Rank")
# Out:
#       Forbes rank                         Name       city  \
# Rank
# 1              49  Reliance Industries Limited     Mumbai
# 2              55          State Bank of India     Mumbai
# 3              65                    HDFC Bank     Mumbai
# 4              70   Life Insurance Corporation  New Delhi
# 5             142                   ICICI Bank     Mumbai
# ...           ...                          ...        ...
# 65           1895     Dr. Reddy's Laboratories  Hyderabad
# 66           1908              Varun Beverages    Gurgaon
# 67           1949                        CIFCL    Chennai
# 68           1957                         NMDC  Hyderabad
# 69           1980                    ABB India  Bangalore
#
#       Revenue(billions US$)  Profit(billions US$)  Assets(billions US$)  \
# Rank
# 1                     108.8                   8.4                 210.5
# 2                      71.8                   8.1                 807.4
# ...

# %%
df['Name'].unique()
# Out:
# array(['Reliance Industries Limited', 'State Bank of India', 'HDFC Bank',
#        'Life Insurance Corporation', 'ICICI Bank',
#        'Oil and Natural Gas Corporation', 'Indian Oil Corporation',
#        'Tata Motors', 'Axis Bank', 'NTPC Limited', 'Larsen & Toubro',
#        'Tata Consultancy Services', 'Bank of Baroda',
#        'Kotak Mahindra Bank', 'Bharti Airtel', 'Coal India',
#        'Canara Bank', 'Power Finance Corporation', 'Bharat Petroleum',
#        'Infosys', 'Punjab National Bank', 'Union Bank of India',
#        'Bajaj Finserv', 'Mahindra & Mahindra', 'JSW Steel Ltd',
#        'Hindalco Industries', 'Grasim Industries', 'HCL Technologies',
#        'ITC Limited', 'Power Grid Corporation of India', 'Tata Steel',
#        'IndusInd Bank', 'Indian Railway Finance Corporation', 'Wipro',
#        'GAIL', 'Indian Bank', 'Vedanta Limited', 'Adani Power',
#        'Bank of India', 'Adani Enterprises', 'Sun Pharmaceutical',
# ...

# %%
df['city'].unique()
# Out:
# array(['Mumbai', 'New Delhi', 'Vadodara', 'Kolkata', 'Bangalore', 'Pune',
#        'Noida', 'Gurgaon', 'Chennai', 'Ahmedabad', 'Kochi', 'Hyderabad'],
#       dtype=object)

# %%
len(df['city'].unique())
# Out:
# 12

# %%
df['Industry'].unique()
# Out:
# array(['Conglomerate', 'Banking', 'Insurance', 'Oil and gas',
#        'Automotive', 'Utilities', 'Capital goods', 'Infotech',
#        'Telecommunication', 'Metals and mining', 'Financials',
#        'Iron and steel', 'Diversified', 'Consumer Goods', 'Energy',
#        'Holding', 'Pharmaceuticals', 'Airline', 'Shipping', 'Chemicals',
#        'Gems and jewellery', 'Retail', 'Renewable energy',
#        'Aerospace and defense', 'Real estate', 'Beverages', 'Mining'],
#       dtype=object)

# %%
len(df['Industry'].unique())
# Out:
# 27

# %%
g = df.groupby("city")

# %%
for city in g:
    print(city)
# Out:
# ('Ahmedabad',     Rank  Forbes rank                Name       city  Revenue(billions US$)  \
# 37    38         1048         Adani Power  Ahmedabad                    6.1
# 39    40         1059   Adani Enterprises  Ahmedabad                   12.7
# 42    43         1219   Adani Ports & SEZ  Ahmedabad                    3.2
# 54    53         1699  Adani Green Energy  Ahmedabad                    1.1
#
#     Profit(billions US$)  Assets(billions US$)  Value(billions US$)  \
# 37                   2.5                  11.1                 29.4
# 39                   0.4                  19.3                 41.9
# 42                   1.0                  14.3                 34.6
# 54                   0.1                  10.6                 34.8
#
#             Industry
# 37            Energy
# 39           Holding
# 42          Shipping
# 54  Renewable energy  )
# ('Bangalore',     Rank  Forbes rank                Name       city  Revenue(billions US$)  \
# ...

# %%
city_profit = g['Profit(billions US$)'].sum().reset_index()

# %%
city_profit = city_profit.sort_values(by = 'Profit(billions US$)',ascending= False)
city_profit.rename(columns={'Headquarters': 'city'}, inplace=True)

# %%
city_profit
# Out:
#          city  Profit(billions US$)
# 7      Mumbai                  63.6
# 8   New Delhi                  24.7
# 1   Bangalore                   7.0
# 6     Kolkata                   6.8
# 3     Gurgaon                   4.1
# 0   Ahmedabad                   4.0
# 10       Pune                   2.4
# 2     Chennai                   2.3
# 11   Vadodara                   2.3
# 9       Noida                   2.1
# 4   Hyderabad                   1.5
# 5       Kochi                   0.5

# %%
plt.figure(figsize=(12, 7))
sns.barplot(
    data=state_profit,
    x='Profit(billions US$)',
    y='city',
    hue='city',
    palette='viridis',
    dodge=False,
    legend=False,
    order=state_profit['city'] 
)

plt.title('Profit Contribution by State')
plt.xlabel('Total Profit')
plt.ylabel('city')
plt.tight_layout()
plt.show()

# %%
Mumbai_data = g.get_group('Mumbai')

# %%
Mumbai_data
# Out:
#     Rank  Forbes rank                           Name    city  \
# 0      1           49    Reliance Industries Limited  Mumbai
# 1      2           55            State Bank of India  Mumbai
# 2      3           65                      HDFC Bank  Mumbai
# 4      5          142                     ICICI Bank  Mumbai
# 7      8          284                    Tata Motors  Mumbai
# 8      9          293                      Axis Bank  Mumbai
# 10    11          398                Larsen & Toubro  Mumbai
# 11    12          412      Tata Consultancy Services  Mumbai
# 13    14          442            Kotak Mahindra Bank  Mumbai
# 18    19          537               Bharat Petroleum  Mumbai
# 21    22          575            Union Bank of India  Mumbai
# 23    24          593            Mahindra & Mahindra  Mumbai
# 24    25          645                  JSW Steel Ltd  Mumbai
# 25    26          684            Hindalco Industries  Mumbai
# ...

# %%
mg = Mumbai_data.groupby('Industry')

# %%
mg

# %%
mg.get_group("Banking")
# Out:
#     Rank  Forbes rank                   Name    city  Revenue(billions US$)  \
# 1      2           55    State Bank of India  Mumbai                   71.8
# 2      3           65              HDFC Bank  Mumbai                   49.3
# 4      5          142             ICICI Bank  Mumbai                   28.5
# 8      9          293              Axis Bank  Mumbai                   16.7
# 13    14          442    Kotak Mahindra Bank  Mumbai                   11.4
# 21    22          575    Union Bank of India  Mumbai                   14.3
# 31    32          901          IndusInd Bank  Mumbai                    6.7
# 38    39         1053          Bank of India  Mumbai                    8.1
# 43    44         1259              IDBI Bank  Mumbai                    3.7
# 57    56         1769               Yes Bank  Mumbai                    4.0
# 60    59         1840  Central Bank of India  Mumbai                    4.3
#
# ...

# %%
revenue_table = Mumbai_data[['city', 'Revenue(billions US$)']].sort_values(by='Revenue(billions US$)', ascending=False)

# 3. Create Profit Table - top companies by profit
profit_table = Mumbai_data[['city', 'Profit(billions US$)']].sort_values(by='Profit(billions US$)', ascending=False)

# %%
industry_profit = Mumbai_data.groupby('Industry')['Profit(billions US$)'].sum().reset_index()
industry_profit = industry_profit.sort_values(by='Profit(billions US$)', ascending=False)

# %%
print("Profit contribution by Industry in Mumbai:")
print(industry_profit)
# Out:
# Profit contribution by Industry in Mumbai:
#              Industry  Profit(billions US$)
# 1             Banking                  31.3
# 4        Conglomerate                   8.4
# 8            Infotech                   5.5
# 0          Automotive                   5.2
# 12        Oil and gas                   3.2
# 11  Metals and mining                   1.6
# 2       Capital goods                   1.6
# 10     Iron and steel                   1.1
# 13    Pharmaceuticals                   1.1
# 9           Insurance                   0.9
# 7             Holding                   0.9
# 3           Chemicals                   0.7
# 5         Diversified                   0.7
# 6          Financials                   0.6
# 15          Utilities                   0.5
# 14             Retail                   0.3

# %%
plt.figure(figsize=(10, 6))
sns.barplot(
    data=industry_profit,
    x='Profit(billions US$)',
    y='Industry',
    hue='Industry',
    palette='viridis',
    dodge=False,
    legend=False
)

plt.title('Profit Contribution by Industry in Mumbai')
plt.xlabel('Total Profit (billions US$)')
plt.ylabel('Industry')
plt.tight_layout()
plt.show()
